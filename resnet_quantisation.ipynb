# %%
import torch
from pathlib import Path
from utils import evaluate_model, dynamic_quantization, static_quantization
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from models.ResNet50 import ResNet50Baseline
import json

# %%
supported_engines = torch.backends.quantized.supported_engines
if 'qnnpack' in supported_engines:
    torch.backends.quantized.engine = 'qnnpack'
if 'fbgemm' in supported_engines:
    torch.backends.quantized.engine = 'fbgemm'
saved_model_path = Path("./saved_models/resnet")
saved_model_path.mkdir(parents=True, exist_ok=True)
torch.backends.quantized.engine
# Out:
# 'qnnpack'

# %%
train_path = Path('/Users/lakshya/quantization/tiny-imagenet-200/train')
test_path = Path('/Users/lakshya/quantization/tiny-imagenet-200/val/processed_val_2')

# %%
transformations = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
train_dataset = datasets.ImageFolder(root=train_path, transform=transformations)
test_dataset = datasets.ImageFolder(root=test_path, transform=transformations)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
baseline_model = torch.load(saved_model_path / "resnet50_baseline_model.pth", map_location="cpu",weights_only=False)
baseline_model.eval()
# Out:
# ResNet50Baseline(
#   (model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Dropout(p=0.4, inplace=False)
#       (1): Linear(in_features=2048, out_features=200, bias=True)
#     )
#   )
# )

# %%
# ===== dynamic quantisation on baseline model. Uses the function inside the utils.py script
quantized_dy_model = dynamic_quantization(baseline_model, (torch.randn(1, 3, 224, 224),))
quantized_dy_model
# Out:
# GraphModule(
#   (model): Module(
#     (conv1): ConvReLU2d(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (1): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (2): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (2): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (3): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (2): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (3): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (4): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (5): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (2): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Module(
#       (0): Dropout(p=0.4, inplace=False)
#       (1): DynamicQuantizedLinear(in_features=2048, out_features=200, dtype=torch.qint8, qscheme=torch.per_channel_affine)
#     )
#   )
# )

# %%
torch.save(quantized_dy_model.state_dict(), saved_model_path / 'resnet50_base_dy_quant_weights.pth')
torch.save(quantized_dy_model, saved_model_path / 'resnet50_base_dy_quant_model.pth')

# %%
quantized_dy_model = torch.load(saved_model_path / "resnet50_base_dy_quant_model.pth", map_location="cpu",weights_only=False)
quantized_dy_model.eval()
# Out:
# /Users/lakshya/PycharmProjects/ModelCompressionAnalysis/.venv/lib/python3.12/site-packages/torch/_utils.py:431: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   device=storage.device,
# GraphModule(
#   (model): Module(
#     (conv1): ConvReLU2d(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (1): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (2): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (2): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (3): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (2): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (3): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (4): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (5): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (2): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): ConvReLU2d(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Module(
#       (0): Dropout(p=0.4, inplace=False)
#       (1): DynamicQuantizedLinear(in_features=2048, out_features=200, dtype=torch.qint8, qscheme=torch.per_channel_affine)
#     )
#   )
# )

# %%
baseline_metrics = evaluate_model(baseline_model, test_loader, 'resnet50')
# Out:
# 100%|███████████████| 157/157 [23:32<00:00,  9.00s/it, Loss=1.6259, Top1=62.42%]

# %%
baseline_metrics
# Out:
# {'top1_acc': 0.6242,
#  'top5_acc': 0.8429,
#  'total_inference_time': 1412.3039989471436,
#  'average_inference_time': 8.9955668722748,
#  'average_loss': 103.42139172402157,
#  'total_batches': 157,
#  'all_losses': [],
#  'all_top1_acc': [],
#  'inference_times': [],
#  'true_labels': [],
#  'predicted_labels': []}

# %%
baseline_dy_metrics = evaluate_model(quantized_dy_model, test_loader, 'resnet50')
# Out:
# [W412 12:55:02.776980000 qlinear_dynamic.cpp:252] Warning: Currently, qnnpack incorrectly ignores reduce_range when it is set to true; this may change in a future release. (function operator())
# 100%|███████████████| 157/157 [23:36<00:00,  9.02s/it, Loss=1.6258, Top1=62.38%]

# %%
baseline_dy_metrics
# Out:
# {'top1_acc': 0.6238,
#  'top5_acc': 0.8429,
#  'total_inference_time': 1416.166141986847,
#  'average_inference_time': 9.020166509470362,
#  'average_loss': 103.40966021179393,
#  'total_batches': 157,
#  'all_losses': [],
#  'all_top1_acc': [],
#  'inference_times': [],
#  'true_labels': [],
#  'predicted_labels': []}

# %%
# ======= Static Quantization. Uses the function inside the utils.py script
calibration_loader = DataLoader(torch.utils.data.Subset(train_dataset, range(1000)), batch_size=64)
base_st_quant_model = static_quantization(baseline_model, (torch.randn(1, 3, 224, 224),), 
                                         calibration_loader)
base_st_quant_model
# Out:
# 100%|███████████████████████████████████████████| 16/16 [02:34<00:00,  9.68s/it]
# GraphModule(
#   (model): Module(
#     (conv1): QuantizedConvReLU2d(3, 64, kernel_size=(7, 7), stride=(2, 2), scale=0.014843720011413097, zero_point=0, padding=(3, 3))
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(64, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.004731349181383848, zero_point=0)
#         (conv2): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.006016128696501255, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.0090074697509408, zero_point=121)
#         (downsample): Module(
#           (0): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.01691831648349762, zero_point=155)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(256, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.004068697802722454, zero_point=0)
#         (conv2): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.007188921794295311, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.007662759628146887, zero_point=128)
#       )
#       (2): Module(
#         (conv1): QuantizedConvReLU2d(256, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.003962324000895023, zero_point=0)
#         (conv2): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.00853211060166359, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.009634348563849926, zero_point=131)
#       )
#     )
#     (layer2): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(256, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.006214894354343414, zero_point=0)
#         (conv2): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(2, 2), scale=0.004459396470338106, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.009484167210757732, zero_point=118)
#         (downsample): Module(
#           (0): QuantizedConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), scale=0.011142932809889317, zero_point=125)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(512, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.003524837549775839, zero_point=0)
#         (conv2): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.0056982445530593395, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.013741091825067997, zero_point=153)
#       )
#       (2): Module(
#         (conv1): QuantizedConvReLU2d(512, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.00411135982722044, zero_point=0)
#         (conv2): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.0035747787915170193, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.007801089435815811, zero_point=128)
#       )
#       (3): Module(
#         (conv1): QuantizedConvReLU2d(512, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.0034229974262416363, zero_point=0)
#         (conv2): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.0035327188670635223, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.007528534159064293, zero_point=138)
#       )
#     )
#     (layer3): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(512, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.006520862691104412, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(2, 2), scale=0.004800372291356325, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.008748791180551052, zero_point=124)
#         (downsample): Module(
#           (0): QuantizedConv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), scale=0.007641063071787357, zero_point=120)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.005182620603591204, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.004892437253147364, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.01244020089507103, zero_point=135)
#       )
#       (2): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.0036128568463027477, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.003004750469699502, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.006268734112381935, zero_point=134)
#       )
#       (3): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.004759836010634899, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.0039047112222760916, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.0099795488640666, zero_point=136)
#       )
#       (4): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.005183843895792961, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.0037661127280443907, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.008229240775108337, zero_point=141)
#       )
#       (5): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.007602442521601915, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.009633461944758892, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.013341514393687248, zero_point=166)
#       )
#     )
#     (layer4): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.008197296410799026, zero_point=0)
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(2, 2), scale=0.007949321530759335, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.03185376524925232, zero_point=125)
#         (downsample): Module(
#           (0): QuantizedConv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), scale=0.0278442595154047, zero_point=103)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.005286785773932934, zero_point=0)
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.0036402393598109484, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.019499460235238075, zero_point=109)
#       )
#       (2): Module(
#         (conv1): QuantizedConvReLU2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.006174493581056595, zero_point=0)
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.0043388730846345425, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.05308884009718895, zero_point=84)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Module(
#       (0): QuantizedDropout(p=0.4, inplace=False)
#       (1): QuantizedLinear(in_features=2048, out_features=200, scale=0.09838435053825378, zero_point=160, qscheme=torch.per_channel_affine)
#     )
#   )
# )

# %%
torch.save(base_st_quant_model.state_dict(), saved_model_path / 'resnet50_base_st_quant_weights.pth')
torch.save(base_st_quant_model, saved_model_path / 'resnet50_base_st_quant_model.pth')

# %%
baseline_st_metrics = evaluate_model(base_st_quant_model, test_loader, 'resnet50')
# Out:
# 100%|███████████████| 157/157 [05:53<00:00,  2.25s/it, Loss=1.6228, Top1=62.19%]

# %%
baseline_st_metrics
# Out:
# {'top1_acc': 0.6219,
#  'top5_acc': 0.8425,
#  'total_inference_time': 353.2770128250122,
#  'average_inference_time': 2.250172056210269,
#  'average_loss': 103.22040442752231,
#  'total_batches': 157,
#  'all_losses': [],
#  'all_top1_acc': [],
#  'inference_times': [],
#  'true_labels': [],
#  'predicted_labels': []}

# %%
# ======= load the structured + unstructured style pruned ResNet50 model!
sparse_pruned_resnet_model = torch.load(saved_model_path / "resnet50_structured_pruned_SparseML40%_finalized_model.pth",
                                        map_location="cpu",weights_only=False)
sparse_pruned_resnet_model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(176, 176, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(712, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 712, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(712, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(712, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(712, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(712, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(712, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(712, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(712, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(352, 352, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(352, 1432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(712, 1432, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1432, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(352, 352, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(352, 1432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1432, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(352, 352, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(352, 1432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=1432, out_features=200, bias=True)
#   )
# )

# %%
# ======= Dyanamic Quantisation of the structured + unstructured style pruned ResNet50 model!
sparse_pruned_dy_quant = dynamic_quantization(sparse_pruned_resnet_model, 
                                              (torch.randn(1, 3, 224, 224),))

# %%
sparse_pruned_dy_quant
# Out:
# GraphModule(
#   (conv1): ConvReLU2d(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Module(
#     (0): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (downsample): Module(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (2): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Module(
#     (0): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (downsample): Module(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (2): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (3): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Module(
#     (0): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(512, 176, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(176, 176, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1))
#       (downsample): Module(
#         (0): Conv2d(512, 712, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (2): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (3): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (4): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (5): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(712, 176, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(176, 712, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Module(
#     (0): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(712, 352, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(352, 352, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(352, 1432, kernel_size=(1, 1), stride=(1, 1))
#       (downsample): Module(
#         (0): Conv2d(712, 1432, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(1432, 352, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(352, 352, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(352, 1432, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (2): Module(
#       (conv1): ConvReLU2d(
#         (0): Conv2d(1432, 352, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): ConvReLU2d(
#         (0): Conv2d(352, 352, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv3): Conv2d(352, 1432, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Module(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): DynamicQuantizedLinear(in_features=1432, out_features=200, dtype=torch.qint8, qscheme=torch.per_channel_affine)
#   )
# )

# %%
torch.save(sparse_pruned_dy_quant.state_dict(), saved_model_path / 'resnet50_sparse_prun_dy_quant_weights.pth')
torch.save(sparse_pruned_dy_quant, saved_model_path / 'resnet50_sparse_prun_dy_quant_model.pth')

# %%
sparse_prun_base_metrics = evaluate_model(sparse_pruned_resnet_model, test_loader, 'resnet50')
# Out:
# 100%|███████████████| 157/157 [20:49<00:00,  7.96s/it, Loss=1.6869, Top1=63.18%]

# %%
sparse_prun_base_metrics
# Out:
# {'top1_acc': 0.6318,
#  'top5_acc': 0.8495,
#  'total_inference_time': 1249.0078840255737,
#  'average_inference_time': 7.955464229462253,
#  'average_loss': 107.34647544933732,
#  'total_batches': 157,
#  'all_losses': [],
#  'all_top1_acc': [],
#  'inference_times': [],
#  'true_labels': [],
#  'predicted_labels': []}

# %%
sparse_prun_dy_quant_metrics = evaluate_model(sparse_pruned_dy_quant, test_loader, 'resnet50')
# Out:
# 100%|███████████████| 157/157 [19:12<00:00,  7.34s/it, Loss=1.6876, Top1=63.13%]

# %%
sparse_prun_dy_quant_metrics
# Out:
# {'top1_acc': 0.6313,
#  'top5_acc': 0.849,
#  'total_inference_time': 1152.8256080150604,
#  'average_inference_time': 7.3428382676118495,
#  'average_loss': 107.38760610446809,
#  'total_batches': 157,
#  'all_losses': [],
#  'all_top1_acc': [],
#  'inference_times': [],
#  'true_labels': [],
#  'predicted_labels': []}

# %%
# ======= Static Quantisation of the structured + unstructured style pruned ResNet50 model!
sparse_pruned_st_quant_model = static_quantization(baseline_model, (torch.randn(1, 3, 224, 224),), 
                                         calibration_loader)
sparse_pruned_st_quant_model
# Out:
# 100%|███████████████████████████████████████████| 16/16 [02:36<00:00,  9.76s/it]
# GraphModule(
#   (model): Module(
#     (conv1): QuantizedConvReLU2d(3, 64, kernel_size=(7, 7), stride=(2, 2), scale=0.014843720011413097, zero_point=0, padding=(3, 3))
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(64, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.004731349181383848, zero_point=0)
#         (conv2): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.006016128696501255, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.0090074697509408, zero_point=121)
#         (downsample): Module(
#           (0): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.01691831648349762, zero_point=155)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(256, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.004068697802722454, zero_point=0)
#         (conv2): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.007188921794295311, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.007662759628146887, zero_point=128)
#       )
#       (2): Module(
#         (conv1): QuantizedConvReLU2d(256, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.003962324000895023, zero_point=0)
#         (conv2): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.00853211060166359, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.009634348563849926, zero_point=131)
#       )
#     )
#     (layer2): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(256, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.006214894354343414, zero_point=0)
#         (conv2): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(2, 2), scale=0.004459396470338106, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.009484167210757732, zero_point=118)
#         (downsample): Module(
#           (0): QuantizedConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), scale=0.011142932809889317, zero_point=125)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(512, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.003524837549775839, zero_point=0)
#         (conv2): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.0056982445530593395, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.013741091825067997, zero_point=153)
#       )
#       (2): Module(
#         (conv1): QuantizedConvReLU2d(512, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.00411135982722044, zero_point=0)
#         (conv2): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.0035747787915170193, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.007801089435815811, zero_point=128)
#       )
#       (3): Module(
#         (conv1): QuantizedConvReLU2d(512, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.0034229974262416363, zero_point=0)
#         (conv2): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.0035327188670635223, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.007528534159064293, zero_point=138)
#       )
#     )
#     (layer3): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(512, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.006520862691104412, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(2, 2), scale=0.004800372291356325, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.008748791180551052, zero_point=124)
#         (downsample): Module(
#           (0): QuantizedConv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), scale=0.007641063071787357, zero_point=120)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.005182620603591204, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.004892437253147364, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.01244020089507103, zero_point=135)
#       )
#       (2): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.0036128568463027477, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.003004750469699502, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.006268734112381935, zero_point=134)
#       )
#       (3): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.004759836010634899, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.0039047112222760916, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.0099795488640666, zero_point=136)
#       )
#       (4): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.005183843895792961, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.0037661127280443907, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.008229240775108337, zero_point=141)
#       )
#       (5): Module(
#         (conv1): QuantizedConvReLU2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.007602442521601915, zero_point=0)
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.009633461944758892, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), scale=0.013341514393687248, zero_point=166)
#       )
#     )
#     (layer4): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.008197296410799026, zero_point=0)
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(2, 2), scale=0.007949321530759335, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.03185376524925232, zero_point=125)
#         (downsample): Module(
#           (0): QuantizedConv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), scale=0.0278442595154047, zero_point=103)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.005286785773932934, zero_point=0)
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.0036402393598109484, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.019499460235238075, zero_point=109)
#       )
#       (2): Module(
#         (conv1): QuantizedConvReLU2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), scale=0.006174493581056595, zero_point=0)
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.0043388730846345425, zero_point=0, padding=(1, 1))
#         (conv3): QuantizedConv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), scale=0.05308884009718895, zero_point=84)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Module(
#       (0): QuantizedDropout(p=0.4, inplace=False)
#       (1): QuantizedLinear(in_features=2048, out_features=200, scale=0.09838435053825378, zero_point=160, qscheme=torch.per_channel_affine)
#     )
#   )
# )

# %%
torch.save(sparse_pruned_st_quant_model.state_dict(), saved_model_path / 'resnet50_sparse_prun_st_quant_weights.pth')
torch.save(sparse_pruned_st_quant_model, saved_model_path / 'resnet50_sparse_prun_st_quant_model.pth')

# %%
sparse_prun_st_quant_metrics = evaluate_model(sparse_pruned_st_quant_model, test_loader, 'resnet50')
# Out:
# 100%|███████████████| 157/157 [05:49<00:00,  2.22s/it, Loss=1.6228, Top1=62.19%]

# %%
sparse_prun_st_quant_metrics
# Out:
# {'top1_acc': 0.6219,
#  'top5_acc': 0.8425,
#  'total_inference_time': 349.1686441898346,
#  'average_inference_time': 2.2240041031199658,
#  'average_loss': 103.22040442752231,
#  'total_batches': 157,
#  'all_losses': [],
#  'all_top1_acc': [],
#  'inference_times': [],
#  'true_labels': [],
#  'predicted_labels': []}

# %%
all_metrics = {
    "baseline_metrics": baseline_metrics,
    "baseline_dy_metrics": baseline_dy_metrics,
    "baseline_st_metrics": baseline_st_metrics,
    "baseline_sparse_prun_metrics": sparse_prun_base_metrics,
    "sparse_prun_dy_quant_metrics": sparse_prun_dy_quant_metrics,
    "sparse_prun_st_quant_metrics": sparse_prun_st_quant_metrics
}
metrics_folder = Path("./model_metrics/resnet50")
metrics_folder.mkdir(parents=True, exist_ok=True)

# %%
for name, metrics in all_metrics.items():
    with (metrics_folder / f"{name}.json").open("w") as file:
        json.dump(metrics, file, indent=1)
